# %% [markdown]
# # Neural_Network_Image_Classification Convolutional Neural Network

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential, Model
from keras.optimizers import RMSprop
from keras.layers import Activation, Dropout, Flatten, Dense, GlobalMaxPooling2D, Conv2D, MaxPooling2D
from keras.callbacks import CSVLogger
from livelossplot.keras import PlotLossesCallback
import efficientnet.keras as efn
import keras
import matplotlib.pyplot as plt
import pickle
import sys
import numpy as np
import os
from mlxtend.plotting import plot_confusion_matrix
import random
from sklearn.metrics import precision_score, recall_score, f1_score, roc_auc_score, confusion_matrix, classification_report

# %%
image_width, image_height = 200, 200
epochs = 20
batch_size = 32
test_size = 30
input_shape = (image_width, image_height, 3)
file_path_train = "/home/ronaldson_bellande/Desktop/Machine Learning/Project & Research/split_images_folders/train/"
file_path_validation = "/home/ronaldson_bellande/Desktop/Machine Learning/Project & Research/split_images_folders/val/"
file_path_test = "/home/ronaldson_bellande/Desktop/Machine Learning/Project & Research/split_images_folders/test/"

# %%
model = Sequential()

model.add(Conv2D(32, 3, 3, padding='same', input_shape=input_shape, activation='relu'))
model.add(Conv2D(32, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, 3, padding='same', activation='relu'))
model.add(Conv2D(64, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(128, 3, 3, padding='same', activation='relu'))
model.add(Conv2D(128, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Conv2D(256, 3, 3, padding='same', activation='relu'))
model.add(Conv2D(256, 3, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2), padding='same'))

model.add(Flatten())
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))

model.add(Dense(1))
model.add(Activation('sigmoid'))

model.compile(loss='binary_crossentropy',
            optimizer=RMSprop(lr=0.0001),
            metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_11"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_52 (Conv2D)           (None, 67, 67, 32)        896
# _________________________________________________________________
# conv2d_53 (Conv2D)           (None, 23, 23, 32)        9248
# _________________________________________________________________
# max_pooling2d_25 (MaxPooling (None, 11, 11, 32)        0
# _________________________________________________________________
# conv2d_54 (Conv2D)           (None, 4, 4, 64)          18496
# _________________________________________________________________
# conv2d_55 (Conv2D)           (None, 2, 2, 64)          36928
# _________________________________________________________________
# max_pooling2d_26 (MaxPooling (None, 1, 1, 64)          0
# _________________________________________________________________
# conv2d_56 (Conv2D)           (None, 1, 1, 128)         73856
# _________________________________________________________________
# conv2d_57 (Conv2D)           (None, 1, 1, 128)         147584
# _________________________________________________________________
# max_pooling2d_27 (MaxPooling (None, 1, 1, 128)         0
# _________________________________________________________________
# conv2d_58 (Conv2D)           (None, 1, 1, 256)         295168
# _________________________________________________________________
# conv2d_59 (Conv2D)           (None, 1, 1, 256)         590080
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 1, 1, 256)         0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 256)               0
# _________________________________________________________________
# dense_6 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_7 (Dense)              (None, 256)               65792
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 257
# _________________________________________________________________
# activation_2 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 1,304,097
# Trainable params: 1,304,097
# Non-trainable params: 0
# _________________________________________________________________

# %%
scale = 1./255
training_data_image_classification = ImageDataGenerator(rescale= scale, shear_range=0.1, zoom_range=0.1, horizontal_flip=True)
validation_data_image_classification = ImageDataGenerator(rescale= scale)
test_data_image_classification = ImageDataGenerator(rescale= scale)

# %%
training_generator = training_data_image_classification.flow_from_directory(file_path_train,
    target_size=(image_width, image_height),
    batch_size=batch_size, class_mode="binary")
# Out:
# Found 13692 images belonging to 20 classes.

# %%
validation_generator = validation_data_image_classification.flow_from_directory(file_path_validation,
    target_size=(image_width, image_height),
    batch_size=batch_size, class_mode="binary")
# Out:
# Found 1703 images belonging to 20 classes.

# %%
test_generator = test_data_generator.flow_from_directory(file_path_test,
    target_size=(image_width, image_height),
    batch_size=1,
    class_mode="binary", 
    shuffle=False)
# Out:
# Found 1730 images belonging to 20 classes.

# %%
early = keras.callbacks.EarlyStopping(monitor='val_acc', patience=4, verbose=1 )

# %%
trained_model = model.fit_generator(
    training_generator,
    steps_per_epoch=len(training_generator.filenames) // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=len(validation_generator.filenames) // batch_size,
    callbacks=[early],verbose=1)
# Out:
# Epoch 1/20
# 427/427 [==============================] - ETA: 0s - loss: -1576519552.0000 - accuracy: 0.0262WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 361s 845ms/step - loss: -1576519552.0000 - accuracy: 0.0262 - val_loss: -15385419776.0000 - val_accuracy: 0.0259
# Epoch 2/20
# 427/427 [==============================] - ETA: 0s - loss: -1633249525760.0000 - accuracy: 0.0263WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 461s 1s/step - loss: -1633249525760.0000 - accuracy: 0.0263 - val_loss: -8295393263616.0000 - val_accuracy: 0.0259
# Epoch 3/20
# 427/427 [==============================] - ETA: 0s - loss: -111407072804864.0000 - accuracy: 0.0262WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 374s 877ms/step - loss: -111407072804864.0000 - accuracy: 0.0262 - val_loss: -393790653202432.0000 - val_accuracy: 0.0259
# Epoch 4/20
# 427/427 [==============================] - ETA: 0s - loss: -2353078632185856.0000 - accuracy: 0.0262WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 440s 1s/step - loss: -2353078632185856.0000 - accuracy: 0.0262 - val_loss: -6528881792122880.0000 - val_accuracy: 0.0259
# Epoch 5/20
# 427/427 [==============================] - ETA: 0s - loss: -25407284913897472.0000 - accuracy: 0.0263WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 491s 1s/step - loss: -25407284913897472.0000 - accuracy: 0.0263 - val_loss: -60261951690768384.0000 - val_accuracy: 0.0259
# Epoch 6/20
# 427/427 [==============================] - ETA: 0s - loss: -178938095717056512.0000 - accuracy: 0.0261WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 406s 950ms/step - loss: -178938095717056512.0000 - accuracy: 0.0261 - val_loss: -377435231981928448.0000 - val_accuracy: 0.0259
# Epoch 7/20
# 427/427 [==============================] - ETA: 0s - loss: -950133352415887360.0000 - accuracy: 0.0262WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 463s 1s/step - loss: -950133352415887360.0000 - accuracy: 0.0262 - val_loss: -1816698461001613312.0000 - val_accuracy: 0.0259
# Epoch 8/20
# 427/427 [==============================] - ETA: 0s - loss: -3998049403599323136.0000 - accuracy: 0.0263WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 445s 1s/step - loss: -3998049403599323136.0000 - accuracy: 0.0263 - val_loss: -7137257630359093248.0000 - val_accuracy: 0.0254
# Epoch 9/20
# 427/427 [==============================] - ETA: 0s - loss: -14276562551369105408.0000 - accuracy: 0.0263WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 425s 995ms/step - loss: -14276562551369105408.0000 - accuracy: 0.0263 - val_loss: -24045982848903020544.0000 - val_accuracy: 0.0259
# Epoch 10/20
# 427/427 [==============================] - ETA: 0s - loss: -44620517217847476224.0000 - accuracy: 0.0261WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 420s 984ms/step - loss: -44620517217847476224.0000 - accuracy: 0.0261 - val_loss: -71622358957142573056.0000 - val_accuracy: 0.0259
# Epoch 11/20
# 427/427 [==============================] - ETA: 0s - loss: -125342478386929336320.0000 - accuracy: 0.0262WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 387s 907ms/step - loss: -125342478386929336320.0000 - accuracy: 0.0262 - val_loss: -193244551790561591296.0000 - val_accuracy: 0.0259
# Epoch 12/20
# 427/427 [==============================] - ETA: 0s - loss: -321980351759226241024.0000 - accuracy: 0.0261WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 403s 943ms/step - loss: -321980351759226241024.0000 - accuracy: 0.0261 - val_loss: -480308442862226243584.0000 - val_accuracy: 0.0259
# Epoch 13/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0315WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 413s 966ms/step - loss: nan - accuracy: 0.0315 - val_loss: nan - val_accuracy: 0.0401
# Epoch 14/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0399WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 456s 1s/step - loss: nan - accuracy: 0.0399 - val_loss: nan - val_accuracy: 0.0395
# Epoch 15/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0398WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 430s 1s/step - loss: nan - accuracy: 0.0398 - val_loss: nan - val_accuracy: 0.0401
# Epoch 16/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0399WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 414s 968ms/step - loss: nan - accuracy: 0.0399 - val_loss: nan - val_accuracy: 0.0401
# Epoch 17/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0399WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 468s 1s/step - loss: nan - accuracy: 0.0399 - val_loss: nan - val_accuracy: 0.0401
# Epoch 18/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0399WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 411s 963ms/step - loss: nan - accuracy: 0.0399 - val_loss: nan - val_accuracy: 0.0401
# Epoch 19/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0400WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 412s 965ms/step - loss: nan - accuracy: 0.0400 - val_loss: nan - val_accuracy: 0.0401
# Epoch 20/20
# 427/427 [==============================] - ETA: 0s - loss: nan - accuracy: 0.0399WARNING:tensorflow:Early stopping conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 427/427 [==============================] - 464s 1s/step - loss: nan - accuracy: 0.0399 - val_loss: nan - val_accuracy: 0.0395

# %%
model.save_weights("CNN_for_image_detection.h5")

# %%
xlabel = 'Epoch'
legends = ['Training', 'Validation']
ylim_pad = [0.01, 0.1]
plt.figure(figsize=(15, 5))
y1 = trained_model.history['accuracy']
y2 = trained_model.history['val_accuracy']

min_y = min(min(y1), min(y2))-ylim_pad[0]
max_y = max(max(y1), max(y2))+ylim_pad[0]


plt.subplot(121)
plt.plot(y1)
plt.plot(y2)
plt.title('Model Accuracy', fontsize=17)
plt.xlabel(xlabel, fontsize=15)
plt.ylabel('Accuracy', fontsize=15)
plt.ylim(min_y, max_y)
plt.legend(legends, loc='upper left')
plt.grid()
    
y1 = trained_model.history['loss']
y2 = trained_model.history['val_loss']
min_y = min(min(y1), min(y2))-ylim_pad[1]
max_y = max(max(y1), max(y2))+ylim_pad[1]
    
plt.subplot(122)
plt.plot(y1)
plt.plot(y2)

plt.title('Model Loss', fontsize=17)
plt.xlabel(xlabel, fontsize=15)
plt.ylabel('Loss', fontsize=15)
plt.ylim(min_y, max_y)
plt.legend(legends, loc='upper left')
plt.grid()                      
plt.show()

# %%
print("results")
result  = model.evaluate(test_generator, steps=len(test_generator), verbose=2)

print("%s%.2f  "% ("Loss     : ", result[0]))
print("%s%.2f%s"% ("Accuracy : ", result[1]*100, "%"))
# Out:
# results
# 1730/1730 - 12s - loss: nan - accuracy: 0.0399
# Loss     : nan
# Accuracy : 3.99%

# %%
classes = test_generator.class_indices
classes
# Out:
# {'aeroplane': 0,
#  'bicycle': 1,
#  'bird': 2,
#  'boat': 3,
#  'bottle': 4,
#  'bus': 5,
#  'car': 6,
#  'cat': 7,
#  'chair': 8,
#  'cow': 9,
#  'diningtable': 10,
#  'dog': 11,
#  'horse': 12,
#  'motorbike': 13,
#  'person': 14,
#  'pottedplant': 15,
#  'sheep': 16,
#  'sofa': 17,
#  'train': 18,
#  'tvmonitor': 19}

# %%
y_pred = model.predict_generator(test_generator, steps=len(test_generator), verbose=2)  
y_pred = y_pred.argmax(axis=-1)
y_true=test_generator.classes
# Out:
# 1730/1730 - 11s

# %%
image_file_name = "/home/ronaldson_bellande/Desktop/Machine Learning/Project & Research/models_image_files/"

file_path = 'CNN_for_image_detection.h5'
title = file_path.split("/")
model_title = "/".join([i for i in title[3:]])

precision = precision_score(y_true, y_pred, average="weighted") 
recall = recall_score(y_true, y_pred, average="weighted") 
f1 = f1_score(y_true, y_pred, average="weighted") 

print("-"*90)
print("Derived Report")
print("-"*90)
print("%s%.2f%s"% ("Precision     : ", precision*100, "%"))
print("%s%.2f%s"% ("Recall        : ", recall*100,    "%"))
print("%s%.2f%s"% ("F1-Score      : ", f1*100,        "%"))
print("-"*90)
print("\n\n")

CM = confusion_matrix(y_true*10, y_pred*10)
fig, ax = plot_confusion_matrix(conf_mat=CM , figsize=(10,8), hide_ticks=True, cmap=plt.cm.Blues)
plt.xticks(range(len(classes)), classes, fontsize=10)
plt.yticks(range(len(classes)), classes, fontsize=10)
plt.title("Confusion Matrix for Model File (Test Dataset): \n"+model_title, fontsize=10)
fig.savefig(image_file_name, dpi=100)
plt.show()
    

cls_report_print = classification_report(y_true, y_pred, target_names=classes)

cls_report = classification_report(y_true, y_pred, target_names=classes, output_dict=True)

print("\n\n")
print("-"*90)
print("Report for Model File: ", model_title)
print("-"*90)
print(cls_report_print)
print("-"*90)
# Out:
# ------------------------------------------------------------------------------------------
# Derived Report
# ------------------------------------------------------------------------------------------
# Precision     : 0.16%
# Recall        : 3.99%
# F1-Score      : 0.31%
# ------------------------------------------------------------------------------------------
# ------------------------------------------------------------------------------------------
# Report for Model File:
# ------------------------------------------------------------------------------------------
#               precision    recall  f1-score   support
#
#    aeroplane       0.04      1.00      0.08        69
#      bicycle       0.00      0.00      0.00        46
#         bird       0.00      0.00      0.00        78
#         boat       0.00      0.00      0.00        47
#       bottle       0.00      0.00      0.00        40
#          bus       0.00      0.00      0.00        41
#          car       0.00      0.00      0.00        79
#          cat       0.00      0.00      0.00       106
#        chair       0.00      0.00      0.00        56
#          cow       0.00      0.00      0.00        34
#  diningtable       0.00      0.00      0.00        30
#          dog       0.00      0.00      0.00       121
#        horse       0.00      0.00      0.00        47
#    motorbike       0.00      0.00      0.00        44
#       person       0.00      0.00      0.00       689
#  pottedplant       0.00      0.00      0.00        29
#        sheep       0.00      0.00      0.00        35
#         sofa       0.00      0.00      0.00        40
#        train       0.00      0.00      0.00        54
#    tvmonitor       0.00      0.00      0.00        45
#
#     accuracy                           0.04      1730
#    macro avg       0.00      0.05      0.00      1730
# weighted avg       0.00      0.04      0.00      1730
#
# ------------------------------------------------------------------------------------------

# %%
numofbatch = len(test_generator)

batch_no = random.randint(0, numofbatch-1)

y_img_batch, y_true_batch = test_generator[batch_no] 
y_true_batch = y_true_batch.argmax(axis=-1)

y_pred_batch = model.predict(y_img_batch)
y_pred_batch = y_pred_batch.argmax(axis=-1)


sizeofbatch = (y_true_batch)
print("-"*35)
print("%s%d"%     ("Selected Batch No       : ", batch_no))
print("-"*35)
print("%s%d"%     ("Batch Size              : ", (y_pred_batch)))
print("-"*35)
print("%s%.2f%s"% ("Accuracy                : ", np.mean(y_true==y_pred)*100, "%"))
print("-"*35)
# Out:
# -----------------------------------
# Selected Batch No       : 1036
# -----------------------------------
# Batch Size              : 0
# -----------------------------------
# Accuracy                : 3.99%
# -----------------------------------

# %%
def show_predictions(test_generator, y_true, y_pred, subplot_params, plot_params, class_map, testing_dir, image_file_name, count=8, sample=True):
    fig, axs = get_fig_axs(subplot_params)
    plt.rcParams.update({'axes.titlesize': plot_params["axes.titlesize"]})
    plt.subplots_adjust(hspace=subplot_params["hspace"], wspace=subplot_params["wspace"])
    image_file_name = "/home/ronaldson_bellande/Desktop/Machine Learning/Project & Research/models_image_files/"
    file_names = test_generator.filenames
    
    m = {}
    length = len(y_true)

    for i in range(0, count): 
        num = i
        if sample:
            num = random.randint(0, length-1)
            while num in m:
                num = int(random.randint(0, length-1))

            m[num]=1


        plt.subplot(subplot_params["nrows"], subplot_params["ncols"], i+1)
        img = plt.imread(file_path_test+"//"+ file_names[num])
        plt.imshow(img, aspect='auto')

        plt.xticks([])
        plt.yticks([])
        
        
        original = class_map[y_true[num]]
        predicted = class_map[y_pred[num]]
        
        
        title_text = ("%s%s%s%s%s"%("True: ", original, "\n", "Pred: ", predicted))
        
        if original==predicted:
            plt.title(title_text)
        else:
            plt.title(title_text, color='red')  

        fig.savefig(image_file_name, dpi=subplot_params["dpi"])

    plt.tight_layout()
    plt.show()

# %%
def get_fig_axs(subplot_params):
    fig, axs = plt.subplots(
        nrows=subplot_params["nrows"], ncols=subplot_params["ncols"], 
        figsize=(subplot_params["figsize_col"], subplot_params["figsize_row"]),
        dpi=subplot_params["dpi"], facecolor=subplot_params["facecolor"], 
        edgecolor=subplot_params["edgecolor"], subplot_kw=subplot_params["subplot_kw"])
        
    return fig, axs

# %%
def subplot(nrows, ncols, dpi):
    subplot_params = {}
    subplot_params["nrows"] = nrows
    subplot_params["ncols"] = ncols

    subplot_params["figsize_col"] = subplot_params["ncols"]*2.5
    subplot_params["figsize_row"] = subplot_params["nrows"]*2.5
    subplot_params["dpi"] = dpi
    subplot_params["facecolor"] = 'w'
    subplot_params["edgecolor"] = 'k'
    subplot_params["subplot_kw"] = {'xticks': [], 'yticks': []}
    subplot_params["axes.titlesize"] = 'small'
    subplot_params["hspace"] = 0.5
    subplot_params["wspace"] = 0.3
    
    return subplot_params

# %%
def reset_plot_params(figsize=(15, 5), title="", xlabel ="", ylabel="", legends=[], title_fontsize = 18, label_fontsize = 14, image_file_name="", save = False, dpi=100, update_image=True):
    plot_params = {}
    
    plot_params["figsize"] = figsize
    
    plot_params["title"] = title
    
    plot_params["xlabel"] = xlabel
    plot_params["ylabel"] = ylabel
    
    plot_params["legends"] = legends 
    
    plot_params["title_fontsize"] = title_fontsize
    plot_params["axes.titlesize"] = "small"
    plot_params["label_fontsize"] = label_fontsize
    
    plot_params["image_file_name"] = image_file_name
    plot_params["save"] = save
    plot_params["update_image"] = update_image
    
    plot_params["subplot"] = None
    return plot_params

# %%
image_file_name_batch = "/result"
image_file_name_sample = "/sample"

batch_size_t = (y_true_batch)

class_map = {v: k for k, v in test_generator.class_indices.items()}

dpi=100

ncols = 8
nrows = 4

count = ncols*nrows

subplot_params = subplot(nrows, ncols, dpi)
plot_params = reset_plot_params()

# %%
show_predictions(test_generator, y_true, y_pred, subplot_params, plot_params, class_map, file_path_test, image_file_name_batch, count=count, sample=True)
